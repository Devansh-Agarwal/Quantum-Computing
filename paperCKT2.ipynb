# %%
import qiskit as qk

# Creating Qubits
qr=qk.QuantumRegister(12)
cr=qk.ClassicalRegister(12)
tr=qk.QuantumRegister(3)
tc=qk.ClassicalRegister(1,'c')
qc= qk.QuantumCircuit(qr,tr,cr,tc)


qc.x(qr[0])##### location of the prize
#print(qr[0:12])
qc.x(qr[5])
qc.h(qr[7])
qc.h(qr[8])
qc.ch(qr[7],qr[8])
###############################################################

qc.x(qr[1])
qc.x(qr[4])
qc.x(qr[7])
qc.mct([qr[1],qr[4]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.ch(tr[1],qr[8])
qc.x(qr[1])
qc.x(qr[4])
qc.x(qr[7])
qc.reset(tr[0:2])
###################################################################
qc.x(qr[2])
qc.x(qr[3])
qc.x(qr[8])
qc.mct([qr[2],qr[3]],tr[0],None)
qc.mct([tr[0],qr[8]],tr[1],None)
qc.ch(tr[1],qr[7])
qc.x(qr[2])
qc.x(qr[3])
qc.x(qr[8])
qc.reset(tr[0:2])
###################################################################
qc.x(qr[0])
qc.x(qr[7])
qc.mct([qr[0],qr[7]],tr[0],None)
qc.cz(tr[0],qr[8])
qc.ch(tr[0],qr[8])
qc.x(qr[0])
qc.x(qr[7])
qc.reset(tr[0:2])
################################################################
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[7])
qc.mct([qr[5],qr[6]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.ch(tr[1],qr[8])
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[7])
qc.reset(tr[0:2])
#####################################################################
qc.x(qr[5])
qc.x(qr[6])
qc.mct([qr[5],qr[6]],tr[0],None)
qc.cx(tr[0],qr[8])
qc.x(qr[5])
qc.x(qr[6])
qc.reset(tr[0:2])
########################################################################
qc.x(qr[5])
qc.x(qr[7])
qc.mct([qr[5],qr[6]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.ch(tr[1],qr[8])
qc.x(qr[5])
qc.x(qr[7])
qc.reset(tr[0:2])
########################################################################
qc.x(qr[1])
qc.x(qr[7])
qc.mct([qr[0],qr[1]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[9])
qc.x(qr[1])
qc.x(qr[7])
qc.reset(tr[0:3])
#########################################################################
qc.x(qr[0])
qc.x(qr[7])
qc.x(qr[8])
qc.mct([qr[0],qr[1]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[9])
qc.x(qr[0])
qc.x(qr[7])
qc.x(qr[8])
qc.reset(tr[0:3])
##########################################################################
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[8])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.ch(tr[2],qr[7])
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[8])
qc.reset(tr[0:3])
###########################################################################
qc.x(qr[5])
qc.x(qr[6])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.cx(tr[1],qr[7])
qc.x(qr[5])
qc.x(qr[6])
qc.reset(tr[0:3])
#########################################################################
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[8])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.ch(tr[2],qr[7])
qc.x(qr[5])
qc.x(qr[6])
qc.x(qr[8])
qc.reset(tr[0:3])
###########################################################################
qc.x(qr[2])
qc.x(qr[8])
qc.mct([qr[0],qr[2]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[10])
qc.x(qr[2])
qc.x(qr[8])
qc.reset(tr[0:3])
##############################################################################
qc.x(qr[0])
qc.x(qr[7])
qc.x(qr[8])
qc.mct([qr[0],qr[2]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[10])
qc.x(qr[0])
qc.x(qr[7])
qc.x(qr[8])
qc.reset(tr[0:3])
########################################################################
qc.x(qr[5])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.mct([tr[1],qr[7]],tr[2],None)
qc.cx(tr[2],qr[8])
qc.x(qr[5])
qc.reset(tr[0:3])
########################################################################
qc.x(qr[5])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.ch(tr[1],qr[7])
qc.x(qr[5])
qc.reset(tr[0:3])
#######################################################################
qc.x(qr[5])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.cx(tr[1],qr[7])######## ambiguity
qc.cx(tr[1],qr[8])
qc.x(qr[5])
qc.reset(tr[0:3])	
##########################################################################
qc.x(qr[6])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.mct([tr[1],qr[7]],tr[2],None)
qc.cx(tr[2],qr[8])
qc.x(qr[6])
qc.reset(tr[0:3])	
######################################################################3
qc.x(qr[6])
qc.mct([qr[5],qr[6]],tr[1],None)
qc.ch(tr[1],qr[7])
qc.x(qr[6])
qc.reset(tr[0:3])
##################################################################
qc.x(qr[2])
qc.x(qr[8])
qc.mct([qr[1],qr[2]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[11])
qc.x(qr[2])
qc.x(qr[8])
qc.reset(tr[0:3])
#################################################################3
qc.x(qr[1])
qc.x(qr[8])
qc.x(qr[7])
qc.mct([qr[1],qr[2]],tr[0],None)
qc.mct([tr[0],qr[7]],tr[1],None)
qc.mct([tr[1],qr[8]],tr[2],None)
qc.cx(tr[2],qr[11])
qc.x(qr[1])
qc.x(qr[8])
qc.x(qr[7])
qc.reset(tr[0:3])
#################################################################



qc.measure(qr[9],cr[9])
qc.measure(qr[10],cr[10])
qc.measure(qr[11],cr[11])


simulator = qk.BasicAer.get_backend('qasm_simulator')

# Simulating the circuit using the simulator to get the result
job = qk.execute(qc, simulator)
result = job.result()

# Getting the aggregated binary outcomes of the circuit.
counts = result.get_counts(qc)
print (counts)
# Out:
# {'0 000000000000': 537, '0 010000000000': 487}

# %%
qc.draw(output = 'mpl')
